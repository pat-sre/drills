# %% [markdown]
# ### The idea
# Create a class that encapsulates a numeric value ex. val = 3.0
# That class allows us to run a method called val.**backward()**
# a = gradClass(3.0)
# b = gradClass(2.0)
# c = a + b
# After running c., all other values that contributed to val, get .grad populated
